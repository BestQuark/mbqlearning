# %% [markdown]
# # Q-learning in MBQC

# %%
include("./MBQsimul.jl");

# %% [markdown]
# Let us check that the MBQsimul module works by implementing the Hadamard gate:

# %%
n=5
G = graph1D(5)
angles = [0, -pi/2, -pi/2, -pi/2, "final state"]
gplot(G, nodelabel=angles)
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.9209430025317717cx, -0.9209431144598489cy), (-0.605930297692808cx, -0.6059308556126058cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.4478163343295714cx, -0.44781705295905166cy), (-0.0796008303725077cx, -0.0796017762070567cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.07851305102980843cx, 0.07851210840744902cy), (0.4556216237898376cx, 0.4556209291825401cy)]), C
# ...

# %%
#prepares initial state
ψ_input = RandomUnitaryMatrix(2)*[1, 0];
ψ_in = graph_with_input(ψ_input, G)
ψ_in = pure2density(ψ_in);

# %%
#Measures X_1 Y_2 Y_3 Y_4 and applies byproduct operator
angles = [0, pi/2, pi/2, pi/2, "state"]
state, s1 = measure_angle(ψ_in, angles[1], 1)
state, s2 = measure_angle(state, angles[2], 2)
state, s3 = measure_angle(state, angles[3], 3)
state, s4 = measure_angle(state, angles[4], 4)

state = partial_trace(state, [1,2,3,4])
#state = apply_byproduct(state, mod(s1+s3+s4,2), mod(s2+s3,2) )
sx,sz = byproduct_track([s1, s2, s3, s4], [1, -1, -1, -1])
state = apply_byproduct(state, sx, sz )
ψ_out = map(x->round(x, digits=3 ),state)

#Check fidelity
round(fidelity(ψ_out, H*pure2density(ψ_input)*H), digits=3)
# Out:
# 1.0

# %% [markdown]
# ## Q-learning for Clifford single-qubit gates

# %% [markdown]
# Let us see if Q-learning finds the measurement pattern for the
# ### Hadamard gate

# %%
#define action space and observation space
actions = [0, 1];
states = prepare_env_states3(5);

# %%
#runs table q_learning for this problem with random ψ_in
rw_fidel = true
q_table_1, rews, _  = q_learning(100, 5, states, actions, H, γ=1, ϵ=0.1,test_batch=5 ,batch = 5, α=0.7, rw_fidel = rw_fidel);
# Out:
# Episode: 100
# Total change of Q-table: 2.474266169727457e-8
# Q-values for state zeros(n): [1.0000000104030597, 0.7570724306116874]

# %%
#plots average reward
plot(1:size(rews[1])[1], rews[1], color=:blue, linewidth=1.5, label="Greedy policy",  framestyle=:box, legend=:bottomright)
if rw_fidel
    plot!(1:size(rews[1])[1], 0.5*ones(size(rews[1])[1]), color=:black, linewidth=2, label="0.5")
    ylabel!("Average fidelity")
elseif !rw_fidel
    plot!(1:size(rews[1])[1], zeros(size(rews[1])[1]), color=:black, linewidth=3, label="0")
    ylabel!("Avg reward")
end
xlabel!("Episodes / 5")
title!("Hadamard learning curve (α=0.7) ")
savefig("./assets/images/clifford julia imgs/new_run/single-lc-H.svg")

# %% [markdown]
# What pattern did the Q-learning agent find for H?

# %%
state_indx = state_indx_f(states)
greedy_actions = []
ψ_input = RandomUnitaryMatrix(2)*[1,0]
ρ =pure2density(graph_with_input(ψ_input, G))
σ = pure2density(H*ψ_input);

state = zeros(n)
info = []
done = false
rw = 0
while !done
    action = eps_greedy_policy2(q_table_1,state_indx[state], eps=0)
    append!(greedy_actions,action2angle(action)) 
    state_n, ρ, rw, done, info = step3(state, ρ, σ, action, n, info=info)
    state = state_n
end
append!(greedy_actions, ["final state"])
println("greedy actions: ", greedy_actions)
print("\nReward ", rw)

gplot(G, nodelabel=greedy_actions)
# Out:
# greedy actions: Any[0.0, -1.5707963267948966, -1.5707963267948966, -1.5707963267948966, "final state"]
#
# Reward 1
# ...

# %% [markdown]
# ### $\pi/2$ gate

# %%
#It also implements the π/2 phase gate
n=5
G = graph1D(5)
angles = [0, 0, -pi/2, 0, "final state"]
gplot(G, nodelabel=angles)
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.9209430583019276cx, 0.9209430586896534cy), (-0.6160132254216526cx, 0.6160132273048726cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.45789934215096817cx, 0.4578993445587191cy), (-0.0834167436299397cx, 0.0834167466857188cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.07469713933812924cx, -0.07469713636305018cy), (0.44558073981091817cx, -0.4455807378562313cy)]), C
# ...

# %%
#runs table q_learning for this problem with random ψ_in
rw_fidel = true
q_table_2, rews, _ = q_learning(200, 5, states, actions,pz, γ=1, ϵ=0.05,test_batch=5, batch = 5, α=0.7, rw_fidel=rw_fidel);
# Out:
# Episode: 200
# Total change of Q-table: 2.362048290294183e-8
# Q-values for state zeros(n): [1.0000000079667046, 0.6468301083178144]

# %%
#plots average reward
plot(1:size(rews[1])[1], rews[1], color=:green, linewidth=1.5, label="Q-learning")
if rw_fidel
    plot!(1:size(rews[1])[1], 0.5*ones(size(rews[1])[1]), color=:black, linewidth=2, label="0.5")
    ylabel!("Avg fidelity")
elseif !rw_fidel
    plot!(1:size(rews[1])[1], zeros(size(rews[1])[1]), color=:black, linewidth=3, label="0")
    ylabel!("Avg reward")
end
xlabel!("Episodes / 5")
title!("π/2 learning curve (α=0.7) ")
savefig("./assets/images/clifford julia imgs/new_run/single-lc-PI2.svg")

# %% [markdown]
# What pattern did the Q-learning agent find for $\pi/2$?

# %%
state_indx = state_indx_f(states)

greedy_actions = []
ψ_input = RandomUnitaryMatrix(2)*[1,0]
ρ =pure2density(graph_with_input(ψ_input, G))
σ = pure2density(pz*ψ_input);

state = zeros(n)
info = []
done = false
rw = 0
while !done
    action = eps_greedy_policy2(q_table_2,state_indx[state], eps=0)
    append!(greedy_actions,action2angle(action)) 
    state_n, ρ, rw, done, info = step3(state, ρ, σ, action, n, info=info)
    state = state_n
end
append!(greedy_actions, ["final"])
println("greedy actions: ", greedy_actions)
print("\nReward ", rw)

gplot(G, nodelabel=greedy_actions)
# Out:
# greedy actions: Any[0.0, 0.0, -1.5707963267948966, 0.0, "final"]
#
# Reward 1
# ...

# %% [markdown]
# ## Question? Does the agent takes more time learning H over R[ $\pi/2$]? Let's see

# %%
rw_fidel = true
nbatch = 10
neps = 500
learn_h = []
learn_r = []

for i in 1:100
    q_table_H, rewsH, conv_H = q_learning(neps, 5, states, actions, H, γ=1, test_batch=10, ϵ=0.05, batch = nbatch, α=0.7, rw_fidel = rw_fidel);
    q_table_R, rewsR, conv_R = q_learning(neps, 5, states, actions,pz, γ=1, test_batch=10, ϵ=0.05, batch = nbatch, α=0.7, rw_fidel=rw_fidel);
    append!(learn_h,conv_H)
    append!(learn_r,conv_R)
end
# Out:
# Episode: 500
# Total change of Q-table: 0.20200870863704035
# Q-values for state zeros(n): [1.0000000027617018, 0.5655114891675734]

# %%
histogram(learn_h ,normalize=true,bins=100, label="H", alpha = 0.3, c=:red, framestyle = :box)
histogram!(learn_r ,normalize=true,bins=100, label="R[π/ 2]", alpha = 0.3, c=:blue)
xlabel!("Episodes/10")
ylabel!("ℙ(learning gate)")
title!("Required episodes to learn gate")
savefig("./assets/images/clifford julia imgs/new_run/single-hist.png")

# %% [markdown]
# # Learning CNOT

# %% [markdown]
# Let us first check if the CNOT can be implemented with the functions of the module MBQsimul:

# %%
### checks step_2d_cnot works (it does😄)

ψ_in1 = RandomUnitaryMatrix(2)*[0,1]
ψ_in2 = RandomUnitaryMatrix(2)*[1,0];
ρ = pure2density(ψ_in1 ⊗ ψ_in2);
σ = pure2density(cnot_ij(1,2,2)*(ψ_in1 ⊗ ψ_in2))

actions = [0, 1];
states = prepare_env_states3(15);

state, ρ, rw, done, info = step_2d_cnot(zeros(15), ρ, σ, 0, 15, rw_fidel=true)
state, ρ, rw, done, info = step_2d_cnot(state , ρ, σ, 0, 15, rw_fidel=true)

state, ρ, rw, done, info = step_2d_cnot(state , ρ, σ, 1, 15, rw_fidel=true)
state, ρ, rw, done, info = step_2d_cnot(state , ρ, σ, 0, 15, rw_fidel=true)

state, ρ, rw, done, info = step_2d_cnot(state , ρ, σ, 1, 15, rw_fidel=true)
state, ρ, rw, done, info = step_2d_cnot(state , ρ, σ, 0, 15, rw_fidel=true)

state, ρ, rw, done, info = step_2d_cnot(state , ρ, σ, 1, 15, rw_fidel=true)
state, ρ, rw, done, info = step_2d_cnot(state , ρ, σ, 1, 15, rw_fidel=true)
state, ρ, rw, done, info = step_2d_cnot(state , ρ, σ, 1, 15, rw_fidel=true)

state, ρ, rw, done, info = step_2d_cnot(state , ρ, σ, 1, 15, rw_fidel=true)
state, ρ, rw, done, info = step_2d_cnot(state , ρ, σ, 0, 15, rw_fidel=true)

state, ρ, rw, done, info = step_2d_cnot(state , ρ, σ, 1, 15, rw_fidel=true)
state, ρ, rw, done, info = step_2d_cnot(state , ρ, σ, 0, 15, rw_fidel=true)

done, rw
# Out:
# UndefVarError: arbitrary_qubit_gate not defined
#
# Stacktrace:
#  [1] step_2d_cnot(state_in::Vector{Float64}, ρ::Matrix{ComplexF64}, σ::Matrix{ComplexF64}, action::Int64, n::Int64; info::Vector{Any}, rw_fidel::Bool)
#    @ Main C:\Users\luism\OneDrive - UBC\2021 Fall\QI Group\MBQC-RL\mbqlearning\MBQsimul.jl:719
#  [2] top-level scope
#    @ In[50]:28
#  [3] eval
#    @ .\boot.jl:360 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1116

# %% [markdown]
# ### Q-learning for CNOT

# %%
actions = [0, 1];
states = prepare_env_states3(15);
n = 15
#runs table q_learning for this problem with random ψ_1 and ψ_2
rw_fidel = true
q_table_cnot, rews_cnot,middle_qubit_action, _ = q_learning_cnot_2(500, n, states, actions, γ=1, ϵ=0.1, batch = 10, α=0.7, rw_fidel = rw_fidel);

# %%
plot(1:size(rews_cnot)[1], rews_cnot, color=:blue, linewidth=1.5, label="Greedy policy", legend = :bottomright, framestyle = :box)
title!("CNOT learning curve (α = 0.7)")
if rw_fidel
    plot!(1:size(rews_cnot)[1], 0.5*ones(size(rews_cnot)[1]), color=:black, linewidth=2, label="0.5")
    ylabel!("Average fidelity")
elseif !rw_fidel
    plot!(1:size(rews_cnot)[1], zeros(size(rews_cnot)[1]), color=:black, linewidth=3, label="0")
    ylabel!("Average reward")
end
xlabel!("Episodes / 10 ")
savefig("./assets/images/clifford julia imgs/new_run/cnot-lc.svg")

# %% [markdown]
# How many iterations does it take the Q-learning agent ($\alpha = 0.7$) to find CNOT

# %%
rw_fidel = true
nbatch = 100
neps = 500
learn_cnot2 = []
actions = [0, 1];
states = prepare_env_states3(15);
n = 15

for i in 1:300
    q_table_cnot2, rews_cnot2,middle_qubit_action2, ep_convs = q_learning_cnot_2(neps, n, states, actions, γ=1, ϵ=0.1, test_batch = 4, batch = nbatch, α=0.7, rw_fidel = rw_fidel);
    append!(learn_cnot2, ep_convs)
end

# %%
histogram(learn_cnot2 ,normalize=true,bins=100, alpha = 0.4, c=:red,framestyle = :box, label=false)
xlabel!("Episodes/100") 
ylabel!("ℙ(learning gate)")
title!("Required episodes to learn CNOT")
savefig("./plots/cnot-hist.png")

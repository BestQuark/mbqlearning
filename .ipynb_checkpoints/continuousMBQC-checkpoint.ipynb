# %%
import os

import gym
from gym import spaces

import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg
import math
from scipy.stats import unitary_group

from stable_baselines3 import PPO
from stable_baselines3.common import results_plotter
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import CheckpointCallback, EveryNTimesteps
# Out:
# C:\Users\luism\anaconda3\envs\gym\lib\site-packages\ale_py\roms\__init__.py:84: DeprecationWarning: Automatic importing of atari-py roms won't be supported in future releases of ale-py. Please migrate over to using `ale-import-roms` OR an ALE-supported ROM package. To make this warning disappear you can run `ale-import-roms --import-from-pkg atari_py.atari_roms`.For more information see: https://github.com/mgbellemare/Arcade-Learning-Environment#rom-management
#   __all__ = _resolve_roms()

# %% [markdown]
# ## Obs space [$X$ $s_1$ $Y$ $s_2$ -1 -1 -1 -1], $s_i \in \{0,1\}$

# %%
class measurement_env(gym.Env):
    metadata = {'render.modes': ['human']}
    
    q_zero = np.array([[1],[0]])
    H = np.array([[1,1],[1,-1]])/np.sqrt(2)
    qubit_plus = H@q_zero
    sx = np.array([[0,1],[1,0]])
    sz = np.array([[1,0],[0,-1]])
    
    def __init__(self, n_qubits, unitary):
        self.n_qubits = n_qubits
        self.unitary = unitary
        self.action_space = spaces.Box(low = np.array([0]), high=np.array([2*np.pi]) )
        self.observation_space = spaces.Box(low=-1*np.ones(2*self.n_qubits), high=2*np.pi*np.ones(2*self.n_qubits))

        self.state = -1*np.ones(2*self.n_qubits)
        self.total_measurements = self.n_qubits
        self.measurements_left = self.n_qubits
        
        st = unitary_group.rvs(2)@q_zero
        #st = q_zero
        self.final_qstate = self.pure2density(self.unitary@st)
        
        self.qstate = self.pure2density(self.create_1D_gs_input(st,self.n_qubits+1))
        

    def step(self, action):
        current_measurement = self.total_measurements - self.measurements_left
        self.state[2*current_measurement] = action[0]

        self.qstate, outcome = self.measure_angle(self.qstate, action[0],current_measurement)
        
        self.state[2*current_measurement+1] = outcome
        
        reward = 0 #fidelity
        
        self.measurements_left -= 1
        
        if self.measurements_left == 0:
            sx = np.array([[0,1],[1,0]])
            sz = np.array([[1,0],[0,-1]])
            last_qbit = self.partial_trace(self.qstate,[i for i in range(0,self.n_qubits)])
            ssx = int(np.sum(self.state[3::4])%2)
            ssz = int(np.sum(self.state[1::4])%2)
            byprod = np.linalg.matrix_power(sx,ssx)@np.linalg.matrix_power(sz,ssz)
            last_qbit = byprod@last_qbit@(np.conjugate(byprod.T))
            reward = self.fidelity(last_qbit, self.final_qstate)
            done = True
        else:
            done = False
        
        info = {}

        return self.state, reward, done, info
        
        
    def reset(self):
        
        self.state = -1*np.ones(2*self.n_qubits)
        self.total_measurements = self.n_qubits
        self.measurements_left = self.n_qubits
        st = unitary_group.rvs(2)@q_zero
        #st = q_zero
        self.final_qstate = self.pure2density(self.unitary@st)
        self.qstate = self.pure2density(self.create_1D_gs_input(st,self.n_qubits+1))
          
        return self.state
        
    def render(self, mode='human', close=False):
        pass

    def controlled_z(self, i, j , n):
        op1, op2 = 1, 2
        for k in range(1,n+1):
            op1 = np.kron(op1, np.eye(2))
            if k in [i,j]:
                op2 = np.kron(op2, np.kron(np.conjugate(np.array([[0],[1]]).T), np.array([[0],[1]])))
            else:
                op2 = np.kron(op2, np.eye(2))
        return op1-op2


    def create_1D_gs(self, n):
        psi = 1
        for i in range(1,n+1):
            psi = np.kron(psi,qubit_plus)
        for i in range(1,n):
            psi = self.controlled_z(i,i+1,n)@psi
        return psi

    def create_1D_gs_input(self, psi, n):
        for i in range(2,n+1):
            psi = np.kron(psi,qubit_plus)
        for i in range(1,n):
            psi = self.controlled_z(i,i+1,n)@psi
        return psi    

    def fidelity(self, sigma, rho):
        srho = linalg.sqrtm(rho)
        prod = srho@sigma@srho
        sprod = linalg.sqrtm(prod)
        return np.abs(np.trace(sprod))

    def pure2density(self, psi):
        return np.kron(psi, np.conjugate(psi.T))

    def measure_angle(self, rho, angle, i):
        n = self.n_qubits+1
        pi0 = 1
        pi1 = 1
        pi0op = np.array([[1, np.exp(-angle*1j)],[np.exp(angle*1j), 1]])/2
        pi1op = np.array([[1,-np.exp(-angle*1j)],[-np.exp(angle*1j), 1]])/2
        for k in range(0,n):
            if k == i:
                pi0 = np.kron(pi0, pi0op)
                pi1 = np.kron(pi1, pi1op)
            else:
                pi0 = np.kron(pi0, np.eye(2))
                pi1 = np.kron(pi1, np.eye(2))
        prob0, prob1 = np.real(np.trace(rho@pi0)), np.real(np.trace(rho@pi1))
        measurement = np.random.choice([0,1], p=[prob0,prob1]/(prob0+prob1))

        if measurement==0:
            rho = pi0@rho@pi0/prob0
        elif measurement==1:
            rho = pi1@rho@pi1/prob1
        
        return rho, measurement

    def partial_trace(self, rho, indices):
        x,y = rho.shape
        n = int(math.log(x,2))
        r = len(indices)
        sigma = np.zeros((int(x/(2**r)), int(y/(2**r))))
        for m in range(0, 2**r):
            qubits = format(m,'0'+f'{r}'+'b')
            ptrace = 1
            for k in range(0,n):
                if k in indices:
                    idx = indices.index(k)
                    if qubits[idx]=='0':
                        ptrace = np.kron(ptrace, np.array([[1],[0]]))
                    elif qubits[idx]=='1':
                        ptrace = np.kron(ptrace, np.array([[0],[1]]))
                else:
                    ptrace = np.kron(ptrace, np.eye(2))
            sigma = sigma + np.conjugate(ptrace.T)@rho@(ptrace)
        return sigma

# %%
def moving_average(values, window):
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, 'valid')


def plot_results(log_folder, title='Learning Curve'):
    
    x, y = ts2xy(load_results(log_folder), 'timesteps')
    y = moving_average(y, window=50)
    x = x[len(x) - len(y):]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel('Steps')
    plt.ylabel('Average Fidelity')
    plt.title(title + " Smoothed")
    plt.show()

# %% [markdown]
# ## Test Hadamard

# %%
q_zero = np.array([[1],[0]])
qubit_plus = H@q_zero
sx = np.array([[0,1],[1,0]])
sz = np.array([[1,0],[0,-1]])
H = np.array([[1,1],[1,-1]])/np.sqrt(2)
env = measurement_env(4,H)
state = env.reset()
done = False
score = 0
n_state, reward, done, info = env.step([0.0])
score += reward  
n_state, reward, done, info = env.step([3*np.pi/2])
score += reward  
n_state, reward, done, info = env.step([3*np.pi/2])
score += reward  
n_state, reward, done, info = env.step([3*np.pi/2])
score += reward  
cond = int(sum(n_state[1::4]))+int(sum(n_state[3::4]))
score
# Out:
# C:\Users\luism\anaconda3\envs\gym\lib\site-packages\gym\spaces\box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# 1.0000000000000002

# %%
env = measurement_env(4,H)
log_dir = "./logs/"
os.makedirs(log_dir, exist_ok=True)
env = Monitor(env, log_dir)

checkpoint_on_event = CheckpointCallback(save_freq=1, save_path='./logs/')
event_callback = EveryNTimesteps(n_steps=1000, callback=checkpoint_on_event)

# %%
model = PPO("MlpPolicy", env, verbose=1);
model.learn(total_timesteps=int(5e5), callback=event_callback);
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4        |
# |    ep_rew_mean     | 0.623    |
# | time/              |          |
# |    fps             | 519      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4          |
# |    ep_rew_mean          | 0.608      |
# | time/                   |            |
# |    fps                  | 475        |
# |    iterations           | 2          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00746088 |
# |    clip_fraction        | 0.0872     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42      |
# |    explained_variance   | -2.23      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00656   |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0105    |
# |    std                  | 0.991      |
# |    value_loss           | 0.0578     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.609       |
# | time/                   |             |
# |    fps                  | 448         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012456497 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.00067     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0219      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 1.01        |
# |    value_loss           | 0.0451      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.627       |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009008734 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | -0.000522   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00731    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 1.03        |
# |    value_loss           | 0.0454      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.664       |
# | time/                   |             |
# |    fps                  | 442         |
# |    iterations           | 5           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008052755 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.0204      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0452      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 1.05        |
# |    value_loss           | 0.0504      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.654        |
# | time/                   |              |
# |    fps                  | 441          |
# |    iterations           | 6            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0061538033 |
# |    clip_fraction        | 0.0803       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.0416       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00175      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00942     |
# |    std                  | 1.05         |
# |    value_loss           | 0.0418       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.686       |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 7           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005373407 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.0312      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00602     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00665    |
# |    std                  | 1.06        |
# |    value_loss           | 0.0395      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.651        |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 8            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0070181563 |
# |    clip_fraction        | 0.0966       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.0603       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00639      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00949     |
# |    std                  | 1.07         |
# |    value_loss           | 0.0377       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.685        |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 9            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0050975867 |
# |    clip_fraction        | 0.0623       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.042        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0064       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00742     |
# |    std                  | 1.07         |
# |    value_loss           | 0.0373       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.689       |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 10          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007963952 |
# |    clip_fraction        | 0.0966      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.0275      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0198      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00987    |
# |    std                  | 1.06        |
# |    value_loss           | 0.0335      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.679        |
# | time/                   |              |
# |    fps                  | 427          |
# |    iterations           | 11           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0073818825 |
# |    clip_fraction        | 0.0945       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.0521       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.014        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00838     |
# |    std                  | 1.05         |
# |    value_loss           | 0.0339       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.726       |
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 12          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009120779 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.0544      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0116     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00962    |
# |    std                  | 1.05        |
# |    value_loss           | 0.0301      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.734        |
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 13           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0069820946 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00522     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0108      |
# |    std                  | 1.04         |
# |    value_loss           | 0.03         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.715       |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 14          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008943669 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.0941      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00718     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 1.02        |
# |    value_loss           | 0.0233      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.739       |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 15          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007124641 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.0876      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00755    |
# |    std                  | 0.993       |
# |    value_loss           | 0.0254      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.746       |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 16          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009218855 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.0928      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0144      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.961       |
# |    value_loss           | 0.0205      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.756        |
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 17           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0062757744 |
# |    clip_fraction        | 0.0865       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0772       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00828      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00689     |
# |    std                  | 0.947        |
# |    value_loss           | 0.02         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.733        |
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 18           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0062174792 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.09         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00596     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.933        |
# |    value_loss           | 0.0196       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.786       |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 19          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008360397 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0183     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.901       |
# |    value_loss           | 0.0147      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.773        |
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 20           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0052526076 |
# |    clip_fraction        | 0.0619       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00175      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00721     |
# |    std                  | 0.887        |
# |    value_loss           | 0.0138       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.759       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 21          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009481443 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.0802      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00261    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0079     |
# |    std                  | 0.847       |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.777       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 22          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007402889 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0223      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000538    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00599    |
# |    std                  | 0.811       |
# |    value_loss           | 0.0113      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.784        |
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 23           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0061809123 |
# |    clip_fraction        | 0.059        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0169      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00687     |
# |    std                  | 0.786        |
# |    value_loss           | 0.012        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.785       |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 24          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004682814 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.0528      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0126      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00354    |
# |    std                  | 0.772       |
# |    value_loss           | 0.011       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.79        |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 25          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008483592 |
# |    clip_fraction        | 0.0431      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.03        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00977    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00253    |
# |    std                  | 0.743       |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.811        |
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 26           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0041901893 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.0493       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00732     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00317     |
# |    std                  | 0.724        |
# |    value_loss           | 0.0107       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.8         |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 27          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.002998448 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0211      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00877    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0019     |
# |    std                  | 0.714       |
# |    value_loss           | 0.00907     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.795       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 28          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.005095492 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0944      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00763     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00342    |
# |    std                  | 0.697       |
# |    value_loss           | 0.00959     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.783       |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 29          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005831522 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.065       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.017       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00348    |
# |    std                  | 0.676       |
# |    value_loss           | 0.0093      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.769        |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 30           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0035398512 |
# |    clip_fraction        | 0.042        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.0678       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.021       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00378     |
# |    std                  | 0.663        |
# |    value_loss           | 0.00961      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.793       |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 31          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.006700149 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | 0.0128      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0106      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00324    |
# |    std                  | 0.651       |
# |    value_loss           | 0.00856     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 4         |
# |    ep_rew_mean          | 0.791     |
# | time/                   |           |
# |    fps                  | 387       |
# |    iterations           | 32        |
# |    time_elapsed         | 169       |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.0051381 |
# |    clip_fraction        | 0.0432    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.98     |
# |    explained_variance   | 0.0697    |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00895  |
# |    n_updates            | 310       |
# |    policy_gradient_loss | -0.00251  |
# |    std                  | 0.64      |
# |    value_loss           | 0.009     |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.777        |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 33           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0072678356 |
# |    clip_fraction        | 0.0549       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.958       |
# |    explained_variance   | -0.0147      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0251       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00402     |
# |    std                  | 0.624        |
# |    value_loss           | 0.00852      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.798        |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 34           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0057898993 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.936       |
# |    explained_variance   | 0.0327       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000283    |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00415     |
# |    std                  | 0.61         |
# |    value_loss           | 0.00938      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.803        |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 35           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0067843366 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.908       |
# |    explained_variance   | 0.0148       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00157     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00528     |
# |    std                  | 0.59         |
# |    value_loss           | 0.00859      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4          |
# |    ep_rew_mean          | 0.789      |
# | time/                   |            |
# |    fps                  | 386        |
# |    iterations           | 36         |
# |    time_elapsed         | 190        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.00751061 |
# |    clip_fraction        | 0.0574     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.872     |
# |    explained_variance   | 0.069      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00117   |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0037    |
# |    std                  | 0.57       |
# |    value_loss           | 0.00839    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.801        |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 37           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0026700504 |
# |    clip_fraction        | 0.0495       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | 0.00979      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00808     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.000571     |
# |    std                  | 0.562        |
# |    value_loss           | 0.00823      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.805       |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 38          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004910062 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.0534      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00022     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.000686   |
# |    std                  | 0.553       |
# |    value_loss           | 0.00829     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.778        |
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 39           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0066553717 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.812       |
# |    explained_variance   | 0.0302       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00538      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00255     |
# |    std                  | 0.54         |
# |    value_loss           | 0.00856      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.804       |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 40          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005216686 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.793      |
# |    explained_variance   | 0.0514      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.000145   |
# |    std                  | 0.531       |
# |    value_loss           | 0.00836     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.803        |
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 41           |
# |    time_elapsed         | 217          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0057871165 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.773       |
# |    explained_variance   | 0.0129       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00573      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00289     |
# |    std                  | 0.518        |
# |    value_loss           | 0.00847      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4          |
# |    ep_rew_mean          | 0.803      |
# | time/                   |            |
# |    fps                  | 384        |
# |    iterations           | 42         |
# |    time_elapsed         | 223        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.00515591 |
# |    clip_fraction        | 0.0659     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.761     |
# |    explained_variance   | 0.00985    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00764    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00231   |
# |    std                  | 0.518      |
# |    value_loss           | 0.00751    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.807        |
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 43           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0041201017 |
# |    clip_fraction        | 0.0553       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.757       |
# |    explained_variance   | 0.0396       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00388     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00144     |
# |    std                  | 0.514        |
# |    value_loss           | 0.0076       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.821       |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 44          |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.003419458 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.743      |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00446    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00056     |
# |    std                  | 0.505       |
# |    value_loss           | 0.00804     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.802        |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 45           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0072359806 |
# |    clip_fraction        | 0.0624       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.721       |
# |    explained_variance   | 0.0392       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00358     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00242     |
# |    std                  | 0.492        |
# |    value_loss           | 0.00819      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.812        |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 46           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0040187445 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.699       |
# |    explained_variance   | 0.0219       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0075      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0018      |
# |    std                  | 0.483        |
# |    value_loss           | 0.00813      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.811        |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 47           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0074775005 |
# |    clip_fraction        | 0.0736       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.684       |
# |    explained_variance   | 0.0234       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00856     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00351     |
# |    std                  | 0.476        |
# |    value_loss           | 0.00802      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.807        |
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 48           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0052469475 |
# |    clip_fraction        | 0.0699       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.668       |
# |    explained_variance   | 0.0157       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0151      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.000468     |
# |    std                  | 0.468        |
# |    value_loss           | 0.00798      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.82         |
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 49           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0072049396 |
# |    clip_fraction        | 0.0624       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.655       |
# |    explained_variance   | 0.0334       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0238      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00223     |
# |    std                  | 0.463        |
# |    value_loss           | 0.00781      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.818        |
# | time/                   |              |
# |    fps                  | 374          |
# |    iterations           | 50           |
# |    time_elapsed         | 273          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0069104554 |
# |    clip_fraction        | 0.0744       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.641       |
# |    explained_variance   | 0.0505       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0137       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00299     |
# |    std                  | 0.456        |
# |    value_loss           | 0.00756      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.814        |
# | time/                   |              |
# |    fps                  | 372          |
# |    iterations           | 51           |
# |    time_elapsed         | 280          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0058984654 |
# |    clip_fraction        | 0.0784       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.628       |
# |    explained_variance   | 0.057        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0178       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00389     |
# |    std                  | 0.45         |
# |    value_loss           | 0.00723      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.801       |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 52          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.006278375 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.0688      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00559     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00117    |
# |    std                  | 0.442       |
# |    value_loss           | 0.00757     |
# -----------------------------------------
# ------------------------------------------
# ...
# |    loss                 | 0.00922     |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | 0.00359     |
# |    std                  | 0.121       |
# |    value_loss           | 0.00877     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.844       |
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 229         |
# |    time_elapsed         | 1307        |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.009263979 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.693       |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00517    |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | 0.00534     |
# |    std                  | 0.121       |
# |    value_loss           | 0.00855     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.825       |
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 230         |
# |    time_elapsed         | 1312        |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.010755806 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.694       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0169      |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | 0.00292     |
# |    std                  | 0.121       |
# |    value_loss           | 0.00926     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.812       |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 231         |
# |    time_elapsed         | 1317        |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.013373116 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.692       |
# |    explained_variance   | 0.27        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0272      |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | 0.00385     |
# |    std                  | 0.121       |
# |    value_loss           | 0.00948     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.845       |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 232         |
# |    time_elapsed         | 1322        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.011214443 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.692       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00501     |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | 0.0054      |
# |    std                  | 0.121       |
# |    value_loss           | 0.00936     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.824       |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 233         |
# |    time_elapsed         | 1328        |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.009820404 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.705       |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00952     |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | 0.00126     |
# |    std                  | 0.119       |
# |    value_loss           | 0.00929     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.84        |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 234         |
# |    time_elapsed         | 1333        |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.014737633 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.724       |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00918     |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | 4.03e-05    |
# |    std                  | 0.116       |
# |    value_loss           | 0.00924     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.834        |
# | time/                   |              |
# |    fps                  | 359          |
# |    iterations           | 235          |
# |    time_elapsed         | 1338         |
# |    total_timesteps      | 481280       |
# | train/                  |              |
# |    approx_kl            | 0.0065808455 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.74         |
# |    explained_variance   | 0.314        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0379       |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | 0.00363      |
# |    std                  | 0.115        |
# |    value_loss           | 0.00934      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.837       |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 236         |
# |    time_elapsed         | 1343        |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.009851143 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.756       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0018      |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | 0.00465     |
# |    std                  | 0.113       |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.817       |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 237         |
# |    time_elapsed         | 1348        |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.017929118 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.768       |
# |    explained_variance   | 0.323       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00547     |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | 0.00484     |
# |    std                  | 0.112       |
# |    value_loss           | 0.00949     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.824       |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 238         |
# |    time_elapsed         | 1354        |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.015755884 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.776       |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0032     |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | 0.0055      |
# |    std                  | 0.111       |
# |    value_loss           | 0.00859     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.846       |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 239         |
# |    time_elapsed         | 1359        |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.013642288 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.787       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00822    |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | 0.00557     |
# |    std                  | 0.11        |
# |    value_loss           | 0.00887     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.827       |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 240         |
# |    time_elapsed         | 1364        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.014816111 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.801       |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0292      |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | 0.00398     |
# |    std                  | 0.108       |
# |    value_loss           | 0.00917     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.816       |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 241         |
# |    time_elapsed         | 1369        |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.008395445 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.811       |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0177      |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | 0.0079      |
# |    std                  | 0.107       |
# |    value_loss           | 0.00894     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.833       |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 242         |
# |    time_elapsed         | 1375        |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.015301708 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.807       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00467    |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | 0.0048      |
# |    std                  | 0.109       |
# |    value_loss           | 0.00947     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.832       |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 243         |
# |    time_elapsed         | 1380        |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.013137266 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.798       |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | 0.0036      |
# |    std                  | 0.109       |
# |    value_loss           | 0.00919     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.838       |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 244         |
# |    time_elapsed         | 1385        |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.012304448 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.801       |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0104      |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | 0.0053      |
# |    std                  | 0.109       |
# |    value_loss           | 0.00906     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.837       |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 245         |
# |    time_elapsed         | 1391        |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.015250578 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.795       |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0176      |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | 0.00473     |
# |    std                  | 0.11        |
# |    value_loss           | 0.00887     |
# -----------------------------------------

# %%
results_plotter.plot_results(['./logs/'], 5e5, results_plotter.X_TIMESTEPS, "Learning Hadamard Continuous")

# %%
plot_results(log_dir)

# %%
obs = env.reset()
for i in range(100):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    if done:
        obs = env.reset()
        print(reward)

env.close()
# Out:
# 0.6361395858287635
# 0.9069450525169376
# 0.7435498077697283
# 0.4654039851774574
# 0.29860875641425705
# 0.5827959351896841
# 0.5323787877742998
# 0.5285731351098706
# 0.462459778526235
# 0.9171835989398459
# 0.6327986515359858
# 0.658300349804968
# 0.6148302888689856
# 0.6580533895026234
# 0.29311769777632407
# 0.48692465213316666
# 0.5046094067374352
# 0.9138781047951996
# 0.8341783671665517
# 0.745360139393499
# 0.17191922455225553
# 0.9455326234984147
# 0.3780261180551379
# 0.2268692138245744
# 0.5711754027247585

# %%
episodes = 20
for episode in range(1,episodes+1):
    state = env.reset()
    done = False
    score = 0
    while not done:
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward  
    print(f'Episode: {episode}, Score: {score}')
# Out:
# Episode: 1, Score: 0.8097461084019575
# Episode: 2, Score: 0.6487170024161448
# Episode: 3, Score: 0.7579979576803378
# Episode: 4, Score: 0.1659624301524337
# Episode: 5, Score: 0.5037548424309757
# Episode: 6, Score: 0.7354376600756527
# Episode: 7, Score: 0.41311286354939425
# Episode: 8, Score: 0.8824794628102733
# Episode: 9, Score: 0.6603434060443298
# Episode: 10, Score: 0.7428675501601822
# Episode: 11, Score: 0.33884322383971593
# Episode: 12, Score: 0.8425200475265893
# Episode: 13, Score: 0.6605409147511163
# Episode: 14, Score: 0.8086056048088028
# Episode: 15, Score: 0.940378062604023
# Episode: 16, Score: 0.18718658854321257
# Episode: 17, Score: 0.5294496082086734
# Episode: 18, Score: 0.49861291120180495
# Episode: 19, Score: 0.9552874287919828
# Episode: 20, Score: 0.6495147816777563

# %% [markdown]
# ## Obs space [$X$ $Y$ -1 -1]

# %%
class measurement_env2(gym.Env):
    metadata = {'render.modes': ['human']}
    
    q_zero = np.array([[1],[0]])
    H = np.array([[1,1],[1,-1]])/np.sqrt(2)
    qubit_plus = H@q_zero
    sx = np.array([[0,1],[1,0]])
    sz = np.array([[1,0],[0,-1]])
    
    def __init__(self, n_qubits, unitary):
        self.n_qubits = n_qubits
        self.unitary = unitary
        self.action_space = spaces.Box(low = np.array([0]), high=np.array([2*np.pi]) )
        self.observation_space = spaces.Box(low=-1*np.ones(self.n_qubits), high=2*np.pi*np.ones(self.n_qubits))

        self.state = -1*np.ones(self.n_qubits)
        self.total_measurements = self.n_qubits
        self.measurements_left = self.n_qubits
        
        st = unitary_group.rvs(2)@q_zero
        #st = q_zero
        self.final_qstate = self.pure2density(self.unitary@st)
        
        self.qstate = self.pure2density(self.create_1D_gs_input(st,self.n_qubits+1))
        
        self.s_even = 0
        self.s_odd = 0

    def step(self, action):
        current_measurement = self.total_measurements - self.measurements_left
        self.state[current_measurement] = action[0]
        corrected_action = action[0]
        if current_measurement%2==0:
            corrected_action =(corrected_action*((-1)**(self.s_even%2)))%(2*math.pi)
        elif current_measurement%2==1:
            corrected_action =(corrected_action*((-1)**(self.s_odd%2)))%(2*math.pi)
        
        self.qstate, outcome = self.measure_angle(self.qstate, corrected_action,current_measurement)
        
        if current_measurement%2==0:
            self.s_odd += int(outcome)
        elif current_measurement%2==1:
            self.s_even += int(outcome)
        
        reward = 0 #fidelity
        
        self.measurements_left -= 1
        if self.measurements_left == 0:
            sx = np.array([[0,1],[1,0]])
            sz = np.array([[1,0],[0,-1]])
            last_qbit = self.partial_trace(self.qstate,[i for i in range(0,self.n_qubits)])
            ssx =int(self.s_even%2)
            ssz =int(self.s_odd%2)
            byprod = np.linalg.matrix_power(sx,ssx)@np.linalg.matrix_power(sz,ssz)
            last_qbit = byprod@last_qbit@(np.conjugate(byprod.T))
            reward = self.fidelity(last_qbit, self.final_qstate)
            done = True
        else:
            done = False
        
        info = {}

        return self.state, reward, done, info
        
        
    def reset(self):
        
        self.state = -1*np.ones(self.n_qubits)
        self.total_measurements = self.n_qubits
        self.measurements_left = self.n_qubits
        st = unitary_group.rvs(2)@q_zero
        #st = q_zero
        self.final_qstate = self.pure2density(self.unitary@st)
        self.qstate = self.pure2density(self.create_1D_gs_input(st,self.n_qubits+1))
        
        self.s_even = 0
        self.s_odd = 0
          
        return self.state
        
    def render(self, mode='human', close=False):
        pass

    def controlled_z(self, i, j , n):
        op1, op2 = 1, 2
        for k in range(1,n+1):
            op1 = np.kron(op1, np.eye(2))
            if k in [i,j]:
                op2 = np.kron(op2, np.kron(np.conjugate(np.array([[0],[1]]).T), np.array([[0],[1]])))
            else:
                op2 = np.kron(op2, np.eye(2))
        return op1-op2


    def create_1D_gs(self, n):
        psi = 1
        for i in range(1,n+1):
            psi = np.kron(psi,qubit_plus)
        for i in range(1,n):
            psi = self.controlled_z(i,i+1,n)@psi
        return psi

    def create_1D_gs_input(self, psi, n):
        for i in range(2,n+1):
            psi = np.kron(psi,qubit_plus)
        for i in range(1,n):
            psi = self.controlled_z(i,i+1,n)@psi
        return psi    

    def fidelity(self, sigma, rho):
        srho = linalg.sqrtm(rho)
        prod = srho@sigma@srho
        sprod = linalg.sqrtm(prod)
        return np.abs(np.trace(sprod))

    def pure2density(self, psi):
        return np.kron(psi, np.conjugate(psi.T))

    def measure_angle(self, rho, angle, i):
        n = self.n_qubits+1
        pi0 = 1
        pi1 = 1
        pi0op = np.array([[1, np.exp(-angle*1j)],[np.exp(angle*1j), 1]])/2
        pi1op = np.array([[1,-np.exp(-angle*1j)],[-np.exp(angle*1j), 1]])/2
        for k in range(0,n):
            if k == i:
                pi0 = np.kron(pi0, pi0op)
                pi1 = np.kron(pi1, pi1op)
            else:
                pi0 = np.kron(pi0, np.eye(2))
                pi1 = np.kron(pi1, np.eye(2))
        prob0, prob1 = np.real(np.trace(rho@pi0)), np.real(np.trace(rho@pi1))
        measurement = np.random.choice([0,1], p=[prob0,prob1]/(prob0+prob1))

        if measurement==0:
            rho = pi0@rho@pi0/prob0
        elif measurement==1:
            rho = pi1@rho@pi1/prob1
        
        return rho, measurement

    def partial_trace(self, rho, indices):
        x,y = rho.shape
        n = int(math.log(x,2))
        r = len(indices)
        sigma = np.zeros((int(x/(2**r)), int(y/(2**r))))
        for m in range(0, 2**r):
            qubits = format(m,'0'+f'{r}'+'b')
            ptrace = 1
            for k in range(0,n):
                if k in indices:
                    idx = indices.index(k)
                    if qubits[idx]=='0':
                        ptrace = np.kron(ptrace, np.array([[1],[0]]))
                    elif qubits[idx]=='1':
                        ptrace = np.kron(ptrace, np.array([[0],[1]]))
                else:
                    ptrace = np.kron(ptrace, np.eye(2))
            sigma = sigma + np.conjugate(ptrace.T)@rho@(ptrace)
        return sigma

# %%
q_zero = np.array([[1],[0]])
qubit_plus = H@q_zero
sx = np.array([[0,1],[1,0]])
sz = np.array([[1,0],[0,-1]])
H = np.array([[1,1],[1,-1]])/np.sqrt(2)
env = measurement_env2(4,H)
state = env.reset()
done = False
score = 0
n_state, reward, done, info = env.step([0.0])
score += reward  
n_state, reward, done, info = env.step([3*np.pi/2])
score += reward  
n_state, reward, done, info = env.step([3*np.pi/2])
score += reward  
n_state, reward, done, info = env.step([3*np.pi/2])
score += reward  
score
# Out:
# 1.0000000001099938

# %%
PZ = np.array([[1,0],[0,1j]])
env = measurement_env2(4,PZ)
state = env.reset()
done = False
score = 0
n_state, reward, done, info = env.step([0.0])
score += reward  
n_state, reward, done, info = env.step([0.0])
score += reward  
n_state, reward, done, info = env.step([-np.pi/2])
score += reward  
n_state, reward, done, info = env.step([0.0])
score += reward  
score
# Out:
# 1.0000000002352933

# %%
env = measurement_env2(4,H)

log_dir = "./logs/"
os.makedirs(log_dir, exist_ok=True)
env = Monitor(env, log_dir)

checkpoint_on_event = CheckpointCallback(save_freq=1, save_path='./logs/')
event_callback = EveryNTimesteps(n_steps=1000, callback=checkpoint_on_event)

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=int(5e4), callback=event_callback)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4        |
# |    ep_rew_mean     | 0.688    |
# | time/              |          |
# |    fps             | 157      |
# |    iterations      | 1        |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.681       |
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 2           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008247834 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -6.13       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0097     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00735    |
# |    std                  | 0.975       |
# |    value_loss           | 0.0675      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.708       |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 3           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.021841893 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.0141     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 1.03        |
# |    value_loss           | 0.0356      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.749       |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 4           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016060852 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.077       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0278     |
# |    std                  | 1.04        |
# |    value_loss           | 0.0301      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.787       |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 5           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019765817 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.0698      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0422     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0299     |
# |    std                  | 1           |
# |    value_loss           | 0.0268      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.84        |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 6           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016523529 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.0551      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0022     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0232     |
# |    std                  | 0.951       |
# |    value_loss           | 0.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.83        |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 7           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011482682 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.0777      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00583    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.897       |
# |    value_loss           | 0.0142      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.858       |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 8           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.016955696 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.0795      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0569     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.835       |
# |    value_loss           | 0.013       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.861       |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 9           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013436582 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00803    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0187     |
# |    std                  | 0.777       |
# |    value_loss           | 0.00946     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.88        |
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 10          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012799585 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0531     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0214     |
# |    std                  | 0.717       |
# |    value_loss           | 0.00757     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.904       |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 11          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012028998 |
# |    clip_fraction        | 0.0624      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.0625      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00669    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.659       |
# |    value_loss           | 0.00766     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.919       |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 12          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011922859 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0213     |
# |    std                  | 0.609       |
# |    value_loss           | 0.00539     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.927       |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 13          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012490751 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0349     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0217     |
# |    std                  | 0.563       |
# |    value_loss           | 0.00447     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.94        |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 14          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009186571 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0402     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 0.523       |
# |    value_loss           | 0.00357     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4          |
# |    ep_rew_mean          | 0.945      |
# | time/                   |            |
# |    fps                  | 358        |
# |    iterations           | 15         |
# |    time_elapsed         | 85         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00915252 |
# |    clip_fraction        | 0.0679     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.729     |
# |    explained_variance   | 0.229      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0506    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0222    |
# |    std                  | 0.483      |
# |    value_loss           | 0.00243    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.953       |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 16          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010710602 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0212     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0188     |
# |    std                  | 0.453       |
# |    value_loss           | 0.00199     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.965        |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 17           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0063249776 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.593       |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.014        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.013       |
# |    std                  | 0.425        |
# |    value_loss           | 0.00167      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.967       |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 18          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011738852 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0579     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.399       |
# |    value_loss           | 0.00109     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.969       |
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 19          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007941229 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.462      |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0331     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.371       |
# |    value_loss           | 0.000813    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.976       |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 20          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009291554 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.395      |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0381     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.349       |
# |    value_loss           | 0.000836    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.977       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 21          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007168349 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.334      |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0186     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.329       |
# |    value_loss           | 0.000529    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.979       |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 22          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010389946 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.274      |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00121     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.308       |
# |    value_loss           | 0.00051     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.979       |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 23          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010404356 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.209      |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0208     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.289       |
# |    value_loss           | 0.000306    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.985       |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 24          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013204312 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.143      |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0328     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.271       |
# |    value_loss           | 0.000252    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.985       |
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 25          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011190167 |
# |    clip_fraction        | 0.0684      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0768     |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0322     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.253       |
# |    value_loss           | 0.000157    |
# -----------------------------------------

# %%
plot_results(log_dir)

# %%
env = measurement_env2(4,H)
obs = env.reset()
for i in range(10):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    print(action)
    if done:
        print("donee, score: ", reward)
        obs = env.reset()

env.close()
# Out:
# [1.4445657]
# [1.5961113]
# [1.5595735]
# [0.]
# donee, score:  0.9991191713029349
# [1.4445657]
# [1.5961113]
# [1.5595735]
# [0.]
# donee, score:  0.9991662216870199
# [1.4445657]
# [1.5961113]
# C:\Users\luism\anaconda3\envs\gym\lib\site-packages\gym\spaces\box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %%
U = unitary_group.rvs(2)
env = measurement_env2(4,U)

log_dir = "./logs/"
os.makedirs(log_dir, exist_ok=True)
env = Monitor(env, log_dir)

checkpoint_on_event = CheckpointCallback(save_freq=1, save_path='./logs/')
event_callback = EveryNTimesteps(n_steps=1000, callback=checkpoint_on_event)
# Out:
# C:\Users\luism\anaconda3\envs\gym\lib\site-packages\gym\spaces\box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %%
model = PPO("MlpPolicy", env, verbose=2)
model.learn(total_timesteps=int(5e4), callback=event_callback)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4        |
# |    ep_rew_mean     | 0.625    |
# | time/              |          |
# |    fps             | 542      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.616       |
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013428553 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | -0.496      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.012       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 1.04        |
# |    value_loss           | 0.0591      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.679       |
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016638376 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.0371      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00839     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 1.08        |
# |    value_loss           | 0.0438      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.756       |
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015353479 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.0535      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00664     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0296     |
# |    std                  | 1.07        |
# |    value_loss           | 0.0441      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4          |
# |    ep_rew_mean          | 0.761      |
# | time/                   |            |
# |    fps                  | 441        |
# |    iterations           | 5          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01596899 |
# |    clip_fraction        | 0.237      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.47      |
# |    explained_variance   | 0.0647     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00967   |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0303    |
# |    std                  | 1.03       |
# |    value_loss           | 0.0292     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.815       |
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 6           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016682718 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.032       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0463     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0272     |
# |    std                  | 0.981       |
# |    value_loss           | 0.0266      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.835       |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 7           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.020821478 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.102       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0335     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0354     |
# |    std                  | 0.922       |
# |    value_loss           | 0.0227      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.861       |
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 8           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011965238 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.0609      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00471    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.86        |
# |    value_loss           | 0.0146      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.882       |
# | time/                   |             |
# |    fps                  | 406         |
# |    iterations           | 9           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014453463 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.098       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0335     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.025      |
# |    std                  | 0.79        |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.891       |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 10          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013418631 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00309    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0218     |
# |    std                  | 0.727       |
# |    value_loss           | 0.00864     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.911       |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 11          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010950483 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0431     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.02       |
# |    std                  | 0.666       |
# |    value_loss           | 0.00636     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4          |
# |    ep_rew_mean          | 0.915      |
# | time/                   |            |
# |    fps                  | 403        |
# |    iterations           | 12         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00933855 |
# |    clip_fraction        | 0.0844     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.976     |
# |    explained_variance   | 0.096      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0162    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0178    |
# |    std                  | 0.62       |
# |    value_loss           | 0.00462    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.915       |
# | time/                   |             |
# |    fps                  | 403         |
# |    iterations           | 13          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009322189 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.013      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.574       |
# |    value_loss           | 0.00427     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.941       |
# | time/                   |             |
# |    fps                  | 403         |
# |    iterations           | 14          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010939505 |
# |    clip_fraction        | 0.0724      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.824      |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.052      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.534       |
# |    value_loss           | 0.00339     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.943       |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 15          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010613828 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.752      |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0381     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.495       |
# |    value_loss           | 0.0025      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.948       |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 16          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009309313 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0191     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.461       |
# |    value_loss           | 0.0019      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.959       |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 17          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009924846 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0308     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.432       |
# |    value_loss           | 0.0016      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.961        |
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 18           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0074506244 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.541       |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0137      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0149      |
# |    std                  | 0.401        |
# |    value_loss           | 0.00113      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.971       |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 19          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009204095 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.47       |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00831    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.374       |
# |    value_loss           | 0.000922    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.973       |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 20          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008936239 |
# |    clip_fraction        | 0.0592      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.403      |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00257    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.351       |
# |    value_loss           | 0.000595    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.976       |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 21          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006978333 |
# |    clip_fraction        | 0.0558      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.337      |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0221     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.328       |
# |    value_loss           | 0.000768    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.983       |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 22          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008350916 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.266      |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0442     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.305       |
# |    value_loss           | 0.000477    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 4         |
# |    ep_rew_mean          | 0.979     |
# | time/                   |           |
# |    fps                  | 409       |
# |    iterations           | 23        |
# |    time_elapsed         | 114       |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0112186 |
# |    clip_fraction        | 0.0592    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.197    |
# |    explained_variance   | 0.291     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00357  |
# |    n_updates            | 220       |
# |    policy_gradient_loss | -0.0124   |
# |    std                  | 0.286     |
# |    value_loss           | 0.00037   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 0.984       |
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 24          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007121181 |
# |    clip_fraction        | 0.0724      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.134      |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0302     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.269       |
# |    value_loss           | 0.000295    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4            |
# |    ep_rew_mean          | 0.985        |
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 25           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0064889155 |
# |    clip_fraction        | 0.0731       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0726      |
# |    explained_variance   | 0.391        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0414      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 0.253        |
# |    value_loss           | 0.00022      |
# ------------------------------------------

# %%
plot_results(log_dir)

# %%
q_zero = np.array([[1],[0]])
rho = pure2density(q_zero)
rho = np.kron(rho,rho)
rho, o = measure_angle(rho, 0, 0, 1)
# Out:
# [[0.5+0.j 0. +0.j 0.5+0.j 0. +0.j]
#  [0. +0.j 0.5+0.j 0. +0.j 0.5+0.j]
#  [0.5+0.j 0. +0.j 0.5+0.j 0. +0.j]
#  [0. +0.j 0.5+0.j 0. +0.j 0.5+0.j]]
